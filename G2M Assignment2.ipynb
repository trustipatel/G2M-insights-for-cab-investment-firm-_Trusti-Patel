# %% [markdown]
# ## 1. Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd 
from numpy.random import randn
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sb

# %% [markdown]
# ## 2. Import all the dataset one by one

# %% [markdown]
# ### 2.1 Import Cab dataset

# %%
address = 'C:/Users/hp/Data Glacier_G2M assignment/DataSets-main/Cab_Data.csv'

data1 = pd.read_csv(address)

data1.columns = ['Transaction ID','Date of Travel','Company','City','KM Travelled','Price Charged','Cost of Trip']

data1
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08-01-2016    Pink Cab     ATLANTA GA
# 1             10000012     06-01-2016    Pink Cab     ATLANTA GA
# 2             10000013     02-01-2016    Pink Cab     ATLANTA GA
# 3             10000014     07-01-2016    Pink Cab     ATLANTA GA
# 4             10000015     03-01-2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
#Check for the duplicate values

data1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 359387    False
# 359388    False
# 359389    False
# 359390    False
# 359391    False
# Length: 359392, dtype: bool

# %%
# Check for the missing values

missing = np.nan
data1.isnull()
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip
# 0               False         False
# 1               False         False
# ...

# %%
# Get the metadata of dataset

data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
# Transaction ID    359392 non-null int64
# Date of Travel    359392 non-null object
# Company           359392 non-null object
# City              359392 non-null object
# KM Travelled      359392 non-null float64
# Price Charged     359392 non-null float64
# Cost of Trip      359392 non-null float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB

# %%
# Check for the datatype of columns

data1.dtypes
# Out:
# Transaction ID      int64
# Date of Travel     object
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
# Deccription of the dataset

data1.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000

# %%
# Unique values for categorical columns

data1['Company'].unique()
# Out:
# array(['Pink Cab', 'Yellow Cab'], dtype=object)

# %% [markdown]
# ### 2.2 Import Customer dataset

# %%
address = 'C:/Users/hp/Data Glacier_G2M assignment/DataSets-main/Customer_ID.csv'

data2 = pd.read_csv(address)

data2.columns = ['Customer ID','Gender','Age','Income (USD/Month)']

data2
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
data2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49166    False
# 49167    False
# 49168    False
# 49169    False
# 49170    False
# Length: 49171, dtype: bool

# %%
missing = np.nan
data2.isnull()
# Out:
#        Customer ID  Gender    Age  Income (USD/Month)
# 0            False   False  False               False
# 1            False   False  False               False
# 2            False   False  False               False
# 3            False   False  False               False
# 4            False   False  False               False
# ...            ...     ...    ...                 ...
# 49166        False   False  False               False
# 49167        False   False  False               False
# 49168        False   False  False               False
# 49169        False   False  False               False
# 49170        False   False  False               False
#
# [49171 rows x 4 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
# Customer ID           49171 non-null int64
# Gender                49171 non-null object
# Age                   49171 non-null int64
# Income (USD/Month)    49171 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
data2.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
data2.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %% [markdown]
# ### 2.3 Import Transaction dataset

# %%
address = 'C:/Users/hp/Data Glacier_G2M assignment/DataSets-main/Transaction_ID.csv'

data3 = pd.read_csv(address)

data3.columns = ['Transaction ID','Customer ID','Payment_Mode']

data3
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
data3.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 440093    False
# 440094    False
# 440095    False
# 440096    False
# 440097    False
# Length: 440098, dtype: bool

# %%
missing = np.nan
data3.isnull()
# Out:
#         Transaction ID  Customer ID  Payment_Mode
# 0                False        False         False
# 1                False        False         False
# 2                False        False         False
# 3                False        False         False
# 4                False        False         False
# ...                ...          ...           ...
# 440093           False        False         False
# 440094           False        False         False
# 440095           False        False         False
# 440096           False        False         False
# 440097           False        False         False
#
# [440098 rows x 3 columns]

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
# Transaction ID    440098 non-null int64
# Customer ID       440098 non-null int64
# Payment_Mode      440098 non-null object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
data3.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
data3.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
data3['Payment_Mode'].unique()
# Out:
# array(['Card', 'Cash'], dtype=object)

# %% [markdown]
# ### 2.4 Import City dataset

# %%
address = 'C:/Users/hp/Data Glacier_G2M assignment/DataSets-main/City.csv'

data4 = pd.read_csv(address)

data4.columns = ['City','Population','Users']

data4
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
data4.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
missing = np.nan
data4.isnull()
# Out:
#      City  Population  Users
# 0   False       False  False
# 1   False       False  False
# 2   False       False  False
# 3   False       False  False
# 4   False       False  False
# 5   False       False  False
# 6   False       False  False
# 7   False       False  False
# 8   False       False  False
# 9   False       False  False
# 10  False       False  False
# 11  False       False  False
# 12  False       False  False
# 13  False       False  False
# 14  False       False  False
# 15  False       False  False
# 16  False       False  False
# 17  False       False  False
# 18  False       False  False
# 19  False       False  False

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# City          20 non-null object
# Population    20 non-null object
# Users         20 non-null object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
data4.dtypes
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
# Cleaning data - rremoving comma from values

population = data4.Population
users = data4.Users


data4['Population'] = data4['Population'].str.replace(',', '').str.replace('$', '').astype(int)
#data4['Population']=data4['Population'].astype(int)

#data4['Users']=data4['Users'].astype(int)
data4['Users'] = data4['Users'].str.replace(',', '').str.replace('$', '').astype(int)

#use other/commented line of code if visible code doesn't work

# %%
data4
# Out:
#                 City  Population   Users
# 0        NEW YORK NY     8405837  302149
# 1         CHICAGO IL     1955130  164468
# 2     LOS ANGELES CA     1595037  144132
# 3           MIAMI FL     1339155   17675
# 4     SILICON VALLEY     1177609   27247
# 5      ORANGE COUNTY     1030185   12994
# 6       SAN DIEGO CA      959307   69995
# 7         PHOENIX AZ      943999    6133
# 8          DALLAS TX      942908   22157
# 9         ATLANTA GA      814885   24701
# 10         DENVER CO      754233   12421
# 11         AUSTIN TX      698371   14978
# 12        SEATTLE WA      671238   25063
# 13         TUCSON AZ      631442    5712
# 14  SAN FRANCISCO CA      629591  213609
# 15     SACRAMENTO CA      545776    7044
# 16     PITTSBURGH PA      542085    3643
# 17     WASHINGTON DC      418859  127001
# 18      NASHVILLE TN      327225    9270
# 19         BOSTON MA      248968   80021

# %%
data4.describe()
# Out:
#          Population          Users
# count  2.000000e+01      20.000000
# mean   1.231592e+06   64520.650000
# std    1.740127e+06   83499.375289
# min    2.489680e+05    3643.000000
# 25%    6.086372e+05   11633.250000
# 50%    7.845590e+05   23429.000000
# 75%    1.067041e+06   91766.000000
# max    8.405837e+06  302149.000000

# %% [markdown]
# ## 3. Merge all the datasets

# %%
f_dataset= data1.merge(data3, on= 'Transaction ID').merge(data2, on ='Customer ID').merge(data4, on = 'City')
f_dataset.head(5)
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 0        10000011     08-01-2016    Pink Cab  ATLANTA GA         30.45
# 1        10351127     21-07-2018  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     23-11-2018  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     06-01-2016    Pink Cab  ATLANTA GA         28.62
# 4        10320494     21-04-2018  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    Income (USD/Month)  Population  Users
# 0               10813      814885  24701
# ...

# %%
#color_theme= ['darkgray', 'lightsalmon']
sb.pairplot(f_dataset.head(1000), hue = 'Company')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
plt.savefig('Pairplot_dataset.png')

# %% [markdown]
# ## 4. Correlation Analysis

# %%
dataset_corr = f_dataset.corr()
dataset_corr
# Out:
#                     Transaction ID  KM Travelled  Price Charged  Cost of Trip  \
# Transaction ID            1.000000     -0.001429      -0.052902     -0.003462
# KM Travelled             -0.001429      1.000000       0.835753      0.981848
# Price Charged            -0.052902      0.835753       1.000000      0.859812
# Cost of Trip             -0.003462      0.981848       0.859812      1.000000
# Customer ID              -0.016912      0.000389      -0.177324      0.003077
# Age                      -0.001267     -0.000369      -0.003084     -0.000189
# Income (USD/Month)       -0.001570     -0.000544       0.003228     -0.000633
# Population                0.023868     -0.002311       0.326589      0.015108
# Users                     0.013526     -0.000428       0.281061      0.023628
#
#                     Customer ID       Age  Income (USD/Month)  Population  \
# Transaction ID        -0.016912 -0.001267           -0.001570    0.023868
# ...

# %% [markdown]
# ## 5. Heatmap to see the correlation

# %%
plt.figure(figsize = (16, 9))

# take upper correlation matrix
matrix = np.triu(dataset_corr)

# Generate heatmap correlation
ax = sb.heatmap(dataset_corr, mask = matrix, cmap = 'rainbow', annot = True, linewidth = 1.5)
# Set the title etc
plt.title('Correlation Heatmap of "G2M Insight for Cab Investment", fontsize = 20')

# Set the size of text
sb.set(font_scale = 1.2)

# %% [markdown]
# #### Observation :  Based on heatmap results we can see that the (Km Travelled & Cost of Trip, Population & Users) have the highest correlation.

# %% [markdown]
# ## 6. Average Users for each cab company

# %%
#company = f_dataset['Company']
#users = f_dataset['Users']
color= ['salmon', 'blue']

#plt.bar(users, company,width='wide', color=color, align='center')


user=f_dataset.groupby('Company')
avg = user.Users.mean()
index = avg.index
value = avg.values

figp, axp = plt.subplots(figsize=(10,7))
axp.pie(value, labels=index, autopct='%1.1f%%')
axp.axis('equal')

plt.title('Users Travel', fontsize = 15)
plt.show()

# %% [markdown]
# #### Observation : From the above Piechart we can see the usage of 'Yellow Cab' is higher that the 'Pink cab'.

# %% [markdown]
# ## 7. Price charged by both company

# %%
plt.figure(figsize = (16, 9))

sb.boxplot(f_dataset['Company'], f_dataset['Price Charged'])
plt.title('Price Charged by Both Companies', fontsize=20)
plt.show()

# %% [markdown]
# #### Observation : As we can see that Price chaged by Yellow cab is higher than the other cab company, yet yellow cab has higher users than pink cab.

# %% [markdown]
# ## 8. Payment transaction and mode

# %%
pt = plt.figure(figsize=(15, 5))

pt.add_subplot(1,2,2)
plt.title("Total Transactions by Payment Mode")
sb.countplot(x="Company", hue="Payment_Mode", data=f_dataset, orient="h", palette="rainbow")


pt.add_subplot(1,2,1)
plt.title("Total Transactions")
sb.countplot(x="Company", data=f_dataset, palette=["#d40404","#ffdd00"])

# %% [markdown]
# #### Observation : Based on the above results, we can see that total transaction between two companies have huge margin gap, as well as payment method also varies for both the companies.  Also most of the yellow cab users pays by card.

# %% [markdown]
# ## 9. Cab users and their income

# %%
plt.figure(figsize = (16, 9))

sb.boxplot(f_dataset['Company'], f_dataset['Income (USD/Month)'])
plt.title('User Income', fontsize=20)
plt.show()

# %% [markdown]
# #### Observation : As we can see, people with income of (8000 - 21000) USD/Month are using cab. And there is not much impact on both cab companies based on income.

# %% [markdown]
# ## 10. Cab users vs. Population

# %%
cu = plt.figure(figsize=(16,8))

# City Population
cu.add_subplot(1,2,1)
plt.title("City Population",fontweight='bold')
sb.barplot(x="City", y="Population", data=f_dataset, palette="pastel")
plt.xticks(rotation=70)


# City Users
cu.add_subplot(1,2,2)
plt.title("Cab Users",fontweight='bold')
sb.barplot(x="City", y="Users", data=f_dataset, palette="pastel")
plt.xticks(rotation=70)

cu.tight_layout()

# %% [markdown]
# #### Observstion : From above bat plot it is clear that higher population has higher cab users. Based on that New York, Chicago followed by Los Angeles have highest cab users. So, investing in these cities can be more profitable.

# %% [markdown]
# ## 11. Cab users and their gender

# %%
gc=f_dataset.groupby(['Company','Gender'])
gc= gc['Customer ID'].nunique()
print(gc)
# Out:
# Company     Gender
# Pink Cab    Female    14819
#             Male      17511
# Yellow Cab  Female    18394
#             Male      21502
# Name: Customer ID, dtype: int64

# %%
color_theme= ['darkgray', 'lightsalmon', 'powderblue', 'gray', 'black']
label = gc.index
values = gc.values
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(gc, labels=label, autopct='%1.1f%%',startangle=90, colors=color_theme)
axp.axis('equal')
plt.title('Cab users based on Gender', fontsize = 20)
plt.show()

# %% [markdown]
# #### Observation : We can notice two things here:  firstly, Male uses more cab than Female and they prefer to travel in Yellow cab.

# %% [markdown]
# ## 12. Cab users their and Age

# %%
plt.figure(figsize = (16, 9))

sb.barplot(f_dataset['Gender'], f_dataset['Age'], hue = f_dataset['Company'])
plt.title('Age of Cab Users', fontsize=20)
plt.show()

# %% [markdown]
# #### Observation : As we see Female and Male of average of 35 use a cab service.

# %% [markdown]
# ## 13. Profit Margin of Cab companies

# %%
company = f_dataset.groupby('Company')
price_charged = company['Price Charged'].mean()
cost_of_trip = company['Cost of Trip'].mean()
ct = cost_of_trip.index
ctv = cost_of_trip.values
pc = price_charged.values

plt.figure(figsize = (12, 6))
plt.bar(ct, pc, label="Revenue")
plt.bar(ct, ctv,label="Profit")
plt.title('Profit Margin')
plt.ylabel('Price Charged')
plt.xlabel('Cost of Trip')
plt.legend()
plt.show()

# %% [markdown]
# #### Observation : As we see Yellow Cab has a higher Profit Margin than Pink Cab.

# %% [markdown]
# ## Results : To conclude, Based on all the data and diagrams, my suggestion to XYZ firm is to go with Yellow Cab for investment. It has more potential to make profit.
